# %% [markdown]
# ## Write ranked timescale to file for GSEA
# Author: Robert Ietswaart
# Date: 20220613
# License: BSD2.
# Load modules j3dl and activate virtual environment using j4RNAdecay on O2.
# Python v3.7.4
#
# Source: `GSEA_20220613.ipynb`
# For Subcellular Timelapse seq project.

# %%
import os
import re
import copy
import numpy as np
import pandas as pd
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)
import logging
import argparse
from __init__ import default_logger_format, default_date_format

# %%
# def main():
np.random.seed(12345)

parser = argparse.ArgumentParser(
    description='Write ranked timescale to file for GSEA.')

args = parser.parse_args("")#EDIT: added "" as argument to run in ipynb instead of .py script

# %%
path = os.path.join('/n','groups','churchman','ri23','bseq','GSEA20230327')

# Add a logger specific to the project and processing stage
logger = logging.getLogger('GSEA')
log_file = os.path.join(path,'LogErr', 'GSEA_preprocess_20230327.log')
formatter = logging.Formatter(default_logger_format,
                              datefmt=default_date_format)
log_handler = logging.FileHandler(log_file)
log_handler.setFormatter(formatter)
logger.addHandler(log_handler)

organisms = ['m','h']
org_map = {'m': 'mouse', 'h': 'human'}
org_red_reps = {'m': ['G_R','H_S'], 'h': ['T', 'U']}

RATE_TYPE = ['half_life_','k_']
rt = RATE_TYPE[0]  ############### use half lives for GSEA
Timescales = ['chr',
              'chr_release',
              'nuc',
              'nucdeg',
              'nucexp',
              'cyto',
              'poly_entry',
              'whole_cell']
Timescales_GSEA = copy.deepcopy(Timescales)
Timescales_GSEA.remove('nucdeg')
Timescales = [rt + ts for ts in Timescales]
Timescales_GSEA = [rt + ts for ts in Timescales_GSEA]

k_bound_lo = 1e-4 #unit: min^-1: 1 per 7 days TEST2_half_life np.log(2)/1e-4 vs 1e-4
k_bound_hi = 1e4 #unit: min^-1: 1 per 6 ms,        TEST2_half_life
T_bound_lo = np.log(2)/k_bound_hi #unit: min, ~6 ms
T_bound_hi = np.log(2)/k_bound_lo #unit: min, ~7 days

OUT_TYPES = ['.Mean', '.MAP', '.0.975.quantile', '.0.025.quantile'] ## use Mean for GSEA, not MAP bc redundant

B = dict()          #Bayes fits file
K = dict()          #Bayes Factor
for o in organisms:    
    path_b = os.path.join('/n','groups','churchman','ri23','bseq','Bayes20230128')
    filename_b = 'Bayes_Rates_20230128_'+ org_map[o] + '.tsv'
    path_k = os.path.join('/n','groups','churchman','ri23','bseq','BayesFactor20221206')
    filename_k = 'Bayes_factor_20230317_' + org_map[o] + '_final.tsv'

    B[o] = pd.read_csv(os.path.join(path_b, filename_b), sep='\t')
    K[o] = pd.read_csv(os.path.join(path_k, filename_k), sep='\t')

# %%
T_bf = 100

C = copy.deepcopy(B)
for o in organisms:
    C[o] = C[o].merge(K[o], on='Gene', how='outer', suffixes=('', '_bf'))
    logger.info('%s all genes: %d' % (org_map[o], len(C[o])))

    for ot in OUT_TYPES[:1]: #only Mean
        for rr in org_red_reps[o]:
            ts = rt + 'chr_release'
            C[o][rr+'.'+ts+ot] = copy.deepcopy(C[o][rr+'.'+ts+'_from_nucdeg'+ot].where(
                    C[o]['PUND'], C[o][rr+'.'+rt+'chr'+ot]))
            ts = rt + 'nucexp'
            C[o][rr+'.'+ts+ot] = copy.deepcopy(C[o][rr+'.'+ts+'_from_nucdeg'+ot].where(
                    C[o]['PUND'], C[o][rr+'.'+ts+'_from_nucres'+ot]))

            for ts in Timescales_GSEA:

                ###Clip range of values beyond numerical integration domain bounds                  
                C[o][rr+'.'+ts+ot].where(((C[o][rr+'.'+ts+ot] <= (np.log(2)/k_bound_lo)) | (C[o][rr+'.'+ts+ot].isna())), 
                                         (np.log(2)/k_bound_lo), inplace=True) 
                C[o][rr+'.'+ts+ot].where(((C[o][rr+'.'+ts+ot] >= (np.log(2)/k_bound_hi)) | (C[o][rr+'.'+ts+ot].isna())), 
                                         (np.log(2)/k_bound_hi), inplace=True)
# Out:
# INFO: [2023-04-05 12:22:49] GSEA - mouse all genes: 17584
# INFO: [2023-04-05 12:22:50] GSEA - human all genes: 18155

# %% [markdown]
# ## Output ranked half life Z-scores
#
# Z scores = log(T1/2)-mean(log(T1/2))/std(log(T1/2)).

# %%
gsea = dict()

for o in organisms:
    logger.info('%s all genes: %d' % (org_map[o], len(C[o])))
    for ot in OUT_TYPES[:1]: #only Mean
        for rr in org_red_reps[o]:
            for ts in Timescales_GSEA:
                cols = ['Gene', 'Symbol']
                cols.extend([rr+'.'+ts+ot for rr in org_red_reps[o]])
                gsea[ts] = copy.deepcopy(C[o][cols])
                gsea[ts] = gsea[ts][~gsea[ts][cols[2:]].isna().all(axis=1)]#filter out NA rows
                logger.info('%s genes without NA half lives %s: %d' % (org_map[o], ts, len(gsea[ts])))
        
                gsea[ts]['timescale'] = gsea[ts][cols[2:]].mean(axis=1, skipna=True)          
                #filter out bounds: cases where both replicates could not estimate timescale
                gsea[ts] = gsea[ts][~gsea[ts]['timescale'].isin([T_bound_lo,T_bound_hi])]
                logger.info('%s genes without timescales equal to domain bounds in %s: %d' % 
                        (org_map[o], ts, len(gsea[ts])))        
                #drop columns that are not used in output
                gsea[ts].drop(['Gene',cols[2],cols[3]], axis=1, inplace=True)
                gsea[ts].sort_values(by='timescale',ascending=False, inplace=True)       
  
                #standardize rates (to Z-score) to enhance learning
                gsea[ts]['timescale'] = np.log(gsea[ts]['timescale'])
                mu = gsea[ts]['timescale'].mean()
                std = gsea[ts]['timescale'].std()
                gsea[ts]['timescale'] = (gsea[ts]['timescale'] - mu) / std
                filename = 'GSEA_'+o+'_all_'+ts+ot+'_z.rnk'
                logger.info(filename)
                gsea[ts].to_csv(os.path.join(path,filename), header=False, index=False, sep='\t')
# Out:
# INFO: [2023-04-05 12:23:22] GSEA - mouse all genes: 17584
# INFO: [2023-04-05 12:23:22] GSEA - mouse genes without NA half lives half_life_chr: 12746
# INFO: [2023-04-05 12:23:22] GSEA - mouse genes without timescales equal to domain bounds in half_life_chr: 12746
# INFO: [2023-04-05 12:23:22] GSEA - GSEA_m_all_half_life_chr.Mean_z.rnk
# INFO: [2023-04-05 12:23:22] GSEA - mouse genes without NA half lives half_life_chr_release: 12746
# INFO: [2023-04-05 12:23:22] GSEA - mouse genes without timescales equal to domain bounds in half_life_chr_release: 12692
# INFO: [2023-04-05 12:23:22] GSEA - GSEA_m_all_half_life_chr_release.Mean_z.rnk
# INFO: [2023-04-05 12:23:22] GSEA - mouse genes without NA half lives half_life_nuc: 12276
# INFO: [2023-04-05 12:23:22] GSEA - mouse genes without timescales equal to domain bounds in half_life_nuc: 12276
# INFO: [2023-04-05 12:23:22] GSEA - GSEA_m_all_half_life_nuc.Mean_z.rnk
# INFO: [2023-04-05 12:23:22] GSEA - mouse genes without NA half lives half_life_nucexp: 12099
# INFO: [2023-04-05 12:23:22] GSEA - mouse genes without timescales equal to domain bounds in half_life_nucexp: 12047
# INFO: [2023-04-05 12:23:22] GSEA - GSEA_m_all_half_life_nucexp.Mean_z.rnk
# INFO: [2023-04-05 12:23:22] GSEA - mouse genes without NA half lives half_life_cyto: 11794
# INFO: [2023-04-05 12:23:22] GSEA - mouse genes without timescales equal to domain bounds in half_life_cyto: 11767
# INFO: [2023-04-05 12:23:22] GSEA - GSEA_m_all_half_life_cyto.Mean_z.rnk
# INFO: [2023-04-05 12:23:22] GSEA - mouse genes without NA half lives half_life_poly_entry: 11492
# INFO: [2023-04-05 12:23:22] GSEA - mouse genes without timescales equal to domain bounds in half_life_poly_entry: 11384
# INFO: [2023-04-05 12:23:22] GSEA - GSEA_m_all_half_life_poly_entry.Mean_z.rnk
# INFO: [2023-04-05 12:23:22] GSEA - mouse genes without NA half lives half_life_whole_cell: 12327
# INFO: [2023-04-05 12:23:22] GSEA - mouse genes without timescales equal to domain bounds in half_life_whole_cell: 12327
# INFO: [2023-04-05 12:23:22] GSEA - GSEA_m_all_half_life_whole_cell.Mean_z.rnk
# INFO: [2023-04-05 12:23:22] GSEA - mouse genes without NA half lives half_life_chr: 12746
# INFO: [2023-04-05 12:23:22] GSEA - mouse genes without timescales equal to domain bounds in half_life_chr: 12746
# INFO: [2023-04-05 12:23:22] GSEA - GSEA_m_all_half_life_chr.Mean_z.rnk
# INFO: [2023-04-05 12:23:22] GSEA - mouse genes without NA half lives half_life_chr_release: 12746
# INFO: [2023-04-05 12:23:22] GSEA - mouse genes without timescales equal to domain bounds in half_life_chr_release: 12692
# INFO: [2023-04-05 12:23:22] GSEA - GSEA_m_all_half_life_chr_release.Mean_z.rnk
# INFO: [2023-04-05 12:23:23] GSEA - mouse genes without NA half lives half_life_nuc: 12276
# INFO: [2023-04-05 12:23:23] GSEA - mouse genes without timescales equal to domain bounds in half_life_nuc: 12276
# INFO: [2023-04-05 12:23:23] GSEA - GSEA_m_all_half_life_nuc.Mean_z.rnk
# INFO: [2023-04-05 12:23:23] GSEA - mouse genes without NA half lives half_life_nucexp: 12099
# INFO: [2023-04-05 12:23:23] GSEA - mouse genes without timescales equal to domain bounds in half_life_nucexp: 12047
# INFO: [2023-04-05 12:23:23] GSEA - GSEA_m_all_half_life_nucexp.Mean_z.rnk
# INFO: [2023-04-05 12:23:23] GSEA - mouse genes without NA half lives half_life_cyto: 11794
# INFO: [2023-04-05 12:23:23] GSEA - mouse genes without timescales equal to domain bounds in half_life_cyto: 11767
# INFO: [2023-04-05 12:23:23] GSEA - GSEA_m_all_half_life_cyto.Mean_z.rnk
# INFO: [2023-04-05 12:23:23] GSEA - mouse genes without NA half lives half_life_poly_entry: 11492
# INFO: [2023-04-05 12:23:23] GSEA - mouse genes without timescales equal to domain bounds in half_life_poly_entry: 11384
# INFO: [2023-04-05 12:23:23] GSEA - GSEA_m_all_half_life_poly_entry.Mean_z.rnk
# INFO: [2023-04-05 12:23:23] GSEA - mouse genes without NA half lives half_life_whole_cell: 12327
# INFO: [2023-04-05 12:23:23] GSEA - mouse genes without timescales equal to domain bounds in half_life_whole_cell: 12327
# INFO: [2023-04-05 12:23:23] GSEA - GSEA_m_all_half_life_whole_cell.Mean_z.rnk
# INFO: [2023-04-05 12:23:23] GSEA - human all genes: 18155
# INFO: [2023-04-05 12:23:23] GSEA - human genes without NA half lives half_life_chr: 12921
# INFO: [2023-04-05 12:23:23] GSEA - human genes without timescales equal to domain bounds in half_life_chr: 12921
# INFO: [2023-04-05 12:23:23] GSEA - GSEA_h_all_half_life_chr.Mean_z.rnk
# INFO: [2023-04-05 12:23:23] GSEA - human genes without NA half lives half_life_chr_release: 12921
# INFO: [2023-04-05 12:23:23] GSEA - human genes without timescales equal to domain bounds in half_life_chr_release: 12900
# INFO: [2023-04-05 12:23:23] GSEA - GSEA_h_all_half_life_chr_release.Mean_z.rnk
# INFO: [2023-04-05 12:23:23] GSEA - human genes without NA half lives half_life_nuc: 13489
# INFO: [2023-04-05 12:23:23] GSEA - human genes without timescales equal to domain bounds in half_life_nuc: 13489
# INFO: [2023-04-05 12:23:23] GSEA - GSEA_h_all_half_life_nuc.Mean_z.rnk
# INFO: [2023-04-05 12:23:23] GSEA - human genes without NA half lives half_life_nucexp: 12690
# INFO: [2023-04-05 12:23:23] GSEA - human genes without timescales equal to domain bounds in half_life_nucexp: 12605
# INFO: [2023-04-05 12:23:23] GSEA - GSEA_h_all_half_life_nucexp.Mean_z.rnk
# INFO: [2023-04-05 12:23:23] GSEA - human genes without NA half lives half_life_cyto: 12454
# INFO: [2023-04-05 12:23:23] GSEA - human genes without timescales equal to domain bounds in half_life_cyto: 12426
# INFO: [2023-04-05 12:23:23] GSEA - GSEA_h_all_half_life_cyto.Mean_z.rnk
# INFO: [2023-04-05 12:23:23] GSEA - human genes without NA half lives half_life_poly_entry: 12068
# INFO: [2023-04-05 12:23:23] GSEA - human genes without timescales equal to domain bounds in half_life_poly_entry: 11923
# INFO: [2023-04-05 12:23:23] GSEA - GSEA_h_all_half_life_poly_entry.Mean_z.rnk
# INFO: [2023-04-05 12:23:23] GSEA - human genes without NA half lives half_life_whole_cell: 11960
# INFO: [2023-04-05 12:23:23] GSEA - human genes without timescales equal to domain bounds in half_life_whole_cell: 11960
# INFO: [2023-04-05 12:23:23] GSEA - GSEA_h_all_half_life_whole_cell.Mean_z.rnk
# INFO: [2023-04-05 12:23:23] GSEA - human genes without NA half lives half_life_chr: 12921
# INFO: [2023-04-05 12:23:23] GSEA - human genes without timescales equal to domain bounds in half_life_chr: 12921
# INFO: [2023-04-05 12:23:23] GSEA - GSEA_h_all_half_life_chr.Mean_z.rnk
# INFO: [2023-04-05 12:23:23] GSEA - human genes without NA half lives half_life_chr_release: 12921
# INFO: [2023-04-05 12:23:23] GSEA - human genes without timescales equal to domain bounds in half_life_chr_release: 12900
# INFO: [2023-04-05 12:23:23] GSEA - GSEA_h_all_half_life_chr_release.Mean_z.rnk
# INFO: [2023-04-05 12:23:23] GSEA - human genes without NA half lives half_life_nuc: 13489
# INFO: [2023-04-05 12:23:23] GSEA - human genes without timescales equal to domain bounds in half_life_nuc: 13489
# INFO: [2023-04-05 12:23:23] GSEA - GSEA_h_all_half_life_nuc.Mean_z.rnk
# INFO: [2023-04-05 12:23:23] GSEA - human genes without NA half lives half_life_nucexp: 12690
# INFO: [2023-04-05 12:23:24] GSEA - human genes without timescales equal to domain bounds in half_life_nucexp: 12605
# INFO: [2023-04-05 12:23:24] GSEA - GSEA_h_all_half_life_nucexp.Mean_z.rnk
# INFO: [2023-04-05 12:23:24] GSEA - human genes without NA half lives half_life_cyto: 12454
# INFO: [2023-04-05 12:23:24] GSEA - human genes without timescales equal to domain bounds in half_life_cyto: 12426
# INFO: [2023-04-05 12:23:24] GSEA - GSEA_h_all_half_life_cyto.Mean_z.rnk
# INFO: [2023-04-05 12:23:24] GSEA - human genes without NA half lives half_life_poly_entry: 12068
# INFO: [2023-04-05 12:23:24] GSEA - human genes without timescales equal to domain bounds in half_life_poly_entry: 11923
# INFO: [2023-04-05 12:23:24] GSEA - GSEA_h_all_half_life_poly_entry.Mean_z.rnk
# INFO: [2023-04-05 12:23:24] GSEA - human genes without NA half lives half_life_whole_cell: 11960
# INFO: [2023-04-05 12:23:24] GSEA - human genes without timescales equal to domain bounds in half_life_whole_cell: 11960
# INFO: [2023-04-05 12:23:24] GSEA - GSEA_h_all_half_life_whole_cell.Mean_z.rnk

# %% [markdown]
# # OLD

# %%
# !pip freeze
# Out:
# asteval==0.9.23
# attrs==19.3.0
# backcall==0.1.0
# backports.zoneinfo==0.2.1
# bleach==3.1.4
# certifi==2021.5.30
# cffi==1.15.0
# charset-normalizer==2.0.1
# cycler==0.10.0
# decorator==4.4.2
# defusedxml==0.6.0
# docopt==0.6.2
# entrypoints==0.3
# future==0.18.2
# goatools==1.1.6
# gtfparse==1.2.1
# idna==3.2
# importlib-metadata==1.5.2
# ipykernel==5.2.0
# ipython==7.13.0
# ipython-genutils==0.2.0
# ipywidgets==7.5.1
# jedi==0.16.0
# Jinja2==2.11.1
# joblib==1.1.0
# jsonschema==3.2.0
# jupyter==1.0.0
# jupyter-client==6.1.2
# jupyter-console==6.1.0
# jupyter-core==4.6.3
# kiwisolver==1.1.0
# llvmlite==0.36.0
# lmfit==1.0.2
# MarkupSafe==1.1.1
# matplotlib==3.2.1
# mistune==0.8.4
# mpmath==1.2.1
# nbconvert==5.6.1
# nbformat==5.0.4
# networkx==2.4
# notebook==6.0.3
# numba==0.53.1
# numba-scipy==0.3.0
# numpy==1.16.5
# pandas==1.0.3
# pandocfilters==1.4.2
# parso==0.6.2
# patsy==0.5.2
# pexpect==4.8.0
# pickleshare==0.7.5
# Pillow==7.0.0
# prometheus-client==0.7.1
# prompt-toolkit==3.0.4
# ptyprocess==0.6.0
# pycparser==2.21
# pydot==1.4.2
# Pygments==2.6.1
# pyparsing==2.4.6
# pyrsistent==0.16.0
# python-dateutil==2.8.1
# pytz==2019.3
# pytz-deprecation-shim==0.1.0.post0
# pyzmq==19.0.0
# qtconsole==4.7.2
# QtPy==1.9.0
# requests==2.26.0
# rpy2==3.5.0
# scikit-learn==1.0.1
# scipy==1.6.2
# seaborn==0.11.2
# Send2Trash==1.5.0
# six==1.14.0
# sklearn==0.0
# statsmodels==0.13.1
# sympy==1.8
# terminado==0.8.3
# testpath==0.4.4
# threadpoolctl==3.0.0
# torch==1.4.0
# torchvision==0.5.0
# tornado==6.0.4
# traitlets==4.3.3
# typing-extensions==4.1.1
# tzdata==2022.1
# tzlocal==4.2
# uncertainties==3.1.5
# urllib3==1.26.6
# virtualenv==16.7.4
# wcwidth==0.1.9
# webencodings==0.5.1
# wget==3.2
# widgetsnbextension==3.5.1
# xlrd==1.2.0
# XlsxWriter==3.0.2
# zipp==3.1.0
